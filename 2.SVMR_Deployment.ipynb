# %%
import pickle
load_model=pickle.load(open("Final_SVMR_Deployment.sav",'rb'))
result=load_model.predict([[162597.70,151377.59,443898.53,191792.06,False]])
result
# Out:
# array([129575.24654449])
