# %%
import pickle
Load_Model = pickle.load(open("Final_MLR_Model.sav",'rb'))
Result = Load_Model.predict([[165349.20,136897.80,471784.10,False,True]])
# Out:
# C:\Users\rajal\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Result
# Out:
# array([[192239.66787833]])
